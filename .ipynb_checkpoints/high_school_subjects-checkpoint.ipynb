# %%
import pandas as pd

# %%
data = pd.read_csv('AU_all_degrees_2026.csv')

# %%
degree_names = data[['Degree Name']]

# %%
data
# Out:
#                                            Degree Name  Guaranteed ATAR score  \
# 0                               Bachelor of Accounting                    NaN
# 1                    Bachelor of Agricultural Sciences                   70.0
# 2                     Bachelor of Architectural Design                   70.0
# 3    Bachelor of Architectural Design majoring in U...                   70.0
# 4                                     Bachelor of Arts                   70.0
# ..                                                 ...                    ...
# 289           Bachelor of Teaching (Primary) (Honours)                   80.0
# 290         Bachelor of Teaching (Secondary) (Honours)                   80.0
# 291                  Bachelor of Veterinary Technology                   80.0
# 292                         Bachelor of Visual Effects                   70.0
# 293               Bachelor of Viticulture and Oenology                   70.0
#
# ...

# %%
import numpy as np
degree_names['Recommmended Stage 2 Subjects'] = np.nan
# Out:
# /var/folders/pb/9424zjnj5xv4rpsmy0pjnv780000gn/T/ipykernel_2994/4131585655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   degree_names['Recommmended Stage 2 Subjects'] = np.nan

# %%
degree_names
# Out:
#                                            Degree Name  \
# 0                               Bachelor of Accounting
# 1                    Bachelor of Agricultural Sciences
# 2                     Bachelor of Architectural Design
# 3    Bachelor of Architectural Design majoring in U...
# 4                                     Bachelor of Arts
# ..                                                 ...
# 289           Bachelor of Teaching (Primary) (Honours)
# 290         Bachelor of Teaching (Secondary) (Honours)
# 291                  Bachelor of Veterinary Technology
# 292                         Bachelor of Visual Effects
# 293               Bachelor of Viticulture and Oenology
#
#      Recommmended Stage 2 Subjects
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 289                            NaN
# ...

# %%
degree_names.iloc[0, 1]
# Out:
# np.float64(nan)

# %%
for i in range(294):
    print(degree_names.iloc[i, 0])
# Out:
# Bachelor of Accounting
# Bachelor of Agricultural Sciences
# Bachelor of Architectural Design
# Bachelor of Architectural Design majoring in Urban Planning
# Bachelor of Arts
# Bachelor of Arts majoring in Aboriginal Studies
# Bachelor of Arts majoring in Anthropology
# Bachelor of Arts majoring in Archaeology and Classical Studies
# Bachelor of Arts majoring in Art History and Visual Culture
# Bachelor of Arts majoring in Chinese Studies
# Bachelor of Arts majoring in Creative Writing
# Bachelor of Arts majoring in Cultural Studies
# Bachelor of Arts majoring in English Literature
# Bachelor of Arts majoring in Environmental Management
# Bachelor of Arts majoring in French Studies
# Bachelor of Arts majoring in Gender and Sexuality Studies
# Bachelor of Arts majoring in Geography
# Bachelor of Arts majoring in German Studies
# Bachelor of Arts majoring in History
# Bachelor of Arts majoring in International Development
# Bachelor of Arts majoring in International Security
# ...

# %%
sace_courses = pd.read_excel('SACE subjects.xlsx')

# %%
stage_2_df = sace_courses[['Stage_2_Code', 'Stage_2_Subject']]

# %%
stage_2_df
# Out:
#     Stage_2_Code                  Stage_2_Subject
# 0         2CVA10                    Creative Arts
# 1         2DCE20                            Dance
# 2         2DMA20                            Drama
# 3         2MEX20               Music Explorations
# 4         2MEB10     Music Performance – Ensemble
# ..           ...                              ...
# 128       2EES20  Earth and Environmental Science
# 129       2NTN20                        Nutrition
# 130       2PYI20                          Physics
# 131       2PSG20                       Psychology
# 132       2STU20               Scientific Studies
#
# [133 rows x 2 columns]

# %%
stage_2 = stage_2_df.Stage_2_Subject.unique()
print(stage_2)
# Out:
# ['Creative Arts' 'Dance' 'Drama' 'Music Explorations'
#  'Music Performance – Ensemble' 'Music Performance – Solo' 'Music Studies'
#  'Visual Arts — Art' 'Visual Arts — Design' 'Accounting'
#  'Business Innovation' 'Digital Communication Solutions'
#  'Industry and Entrepreneurial Solutions' 'Material Solutions'
#  'Robotic and Electronic Systems' 'Digital Technologies'
#  'Information Processing and Publishing' 'Workplace Practices A'
#  'Workplace Practices B' 'Workplace Practices' 'Arts and the Community'
#  'Communication and the Community' 'Foods and the Community'
#  'Health, Recreation, and the Community'
#  'Science, Technology, and the Community' 'Work and the Community'
#  'Humanities and Social Sciences Connections'
#  'Interdisciplinary Connections' 'Practical Connections'
#  'STEM Connections' 'Activating Identities and Futures'
#  'Cross-disciplinary Studies' 'Integrated Learning A'
#  'Integrated Learning B' 'Research Project A' 'Research Project B' nan
# ...

# %%
courses_recommended_4 = [
    ('English', 'Mathematical Methods', 'Specialist Mathematics', 'Accounting'),
    ('Chemistry', 'Mathematical Methods', 'Agricultural Production', 'Agricultural Systems'),
    ('English', 'Mathematical Methods', 'Physics', 'Visual Arts — Design'),
    ('English', 'Mathematical Methods', 'Physics', 'Visual Arts — Design'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Aboriginal Studies'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Ancient Studies', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Visual Arts — Art'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Chinese (continuers)'),
    ('English Literary Studies', 'Modern History', 'Media Studies', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Media Studies'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Geography', 'Society and Culture', 'Earth and Environmental Science'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'French (continuers)'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', "Women's Studies"),
    ('English Literary Studies', 'Geography', 'Society and Culture', 'Earth and Environmental Science'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'German (continuers)'),
    ('English Literary Studies', 'Modern History', 'Ancient Studies', 'Philosophy'),
    ('Economics', 'Modern History', 'Society and Culture', 'Geography'),
    ('English Literary Studies', 'Modern History', 'Legal Studies', 'Politics, Power and People'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Japanese (continuers)'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Legal Studies', 'Politics, Power, and People'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Geography'),
    ('English Literary Studies', 'Media Studies', 'Society and Culture', 'Creative Arts'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Economics'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Philosophy'),
    ('English Literary Studies', 'Modern History', 'Society and Culture', 'Spanish (continuers)')
    ('English', 'Mathematics Methods', 'Business Inovation', 'Economics'),
    ('English', 'Mathematics Methods', 'Physics', 'Geography'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('English', 'Biology', 'Chemistry', 'Child Studies'),
    ('Accounting', 'Economics', 'General Mathematics', 'Business Innovation'),
    ('Accounting', 'Economics', 'Mathematical Methods', 'Business Innovation'),
    ('Accounting', 'Economics', 'General Mathematics', 'Business Innovation'),
    ('Accounting', 'Economics', 'General Mathematics', 'Business Innovation'),
    ('Digital Communication Solutions', 'Economics', 'General Mathematics', 'Business Innovation'),
    ('Digital Communication Solutions', 'Economics', 'Media Studies', 'Business Innovation'),
    ('Economics', 'Business Innovation', 'Tourism', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'Mathematical Methods', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'Chinese (continuers)', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Visual Arts — Design', 'Business Innovation', 'Media Studies', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Digital Communication Solutions'),
    ('Economics', 'Business Innovation', 'Health and Wellbeing', 'Health, Recreation, and the Community'),
    ('Economics', 'Business Innovation', 'Tourism', 'Digital Communication Solutions'),
    ('Biology', 'Chemistry', 'Physical Education', 'Mathematical Methods'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Accounting'),
    ('Economics', 'Business Innovation', 'Mathematical Methods', 'Accounting'),
    ('Economics', 'Business Innovation', 'Mathematical Methods', 'Digital Technologies'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Accounting'),
    ('Economics', 'Business Innovation', 'General Mathematics', 'Legal Studies'),
    ('Media Studies', 'Digital Communication Solutions', 'Society and Culture', 'Communication and the Community'),
    ('Health and Wellbeing', 'Child Studies', 'Biology', 'Society and Culture'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Physics'),
    ('Mathematical Methods', 'Material Solutions', 'Digital Technologies', 'Business Innovation'),
    ('Mathematical Methods', 'Material Solutions', 'Digital Technologies', 'Business Innovation'),
    ('Mathematical Methods', 'Material Solutions', 'Digital Technologies', 'Business Innovation'),
    ('Mathematical Methods', 'Material Solutions', 'Digital Technologies', 'Business Innovation'),
    ('English Literary Studies', 'Creative Arts', 'Visual Arts — Art', 'Media Studies'),
    ('Digital Communication Solutions', 'Creative Arts', 'Visual Arts — Art', 'Media Studies'),
    ('Business Innovation', 'Creative Arts', 'Digital Communication Solutions', 'Media Studies'),
    ('English Literary Studies', 'Philosophy', 'Society and Culture', 'Media Studies'),
    ('Digital Technologies', 'Visual Arts — Design', 'Media Studies', 'Digital Communication Solutions'),
    ('Media Studies', 'Business Innovation', 'Creative Arts', 'Communication and the Community'),
    ('Digital Technologies', 'Visual Arts — Design', 'Mathematical Methods', 'Media Studies'),
    ('Digital Technologies', 'Media Studies', 'Visual Arts — Design', 'Creative Arts'),
    ('Drama', 'Music Performance', 'Creative Arts', 'Dance'),
    ('Media Studies', 'Creative Arts', 'Digital Communication Solutions', 'Visual Arts — Design'),
    ('Legal Studies', 'Society and Culture', 'Psychology', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Psychology', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Aboriginal Studies', 'Modern History'),
    ('Ancient Studies', 'Society and Culture', 'Psychology', 'Modern History'),
    ("Women's studies", 'Society and Culture', 'Health and Wellbeing', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Ancient Studies', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Politics', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Politics', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Politics', 'Geography'),
    ('Legal Studies', 'Society and Culture', 'Economics', 'Modern History'),
    ('Legal Studies', 'Society and Culture', 'Psychology', 'Modern History'),
    ('Digital Technologies', 'Mathematical Methods', 'Information Processing and Publishing', 'Legal Studies'),
    ('Digital Technologies', 'Mathematical Methods', 'Information Processing and Publishing', 'Legal Studies'),
    ('Digital Technologies', 'Mathematical Methods', 'Business Innovation', 'Information Processing and Publishing'),
    ('Chemistry', 'Biology', 'Mathematical Methods', 'Psychology'),
    ('Business Innovation', 'Digital Technologies', 'General Mathematics', 'Information Processing and Publishing'),
    ('Media Studies, Visual Arts — Design, Creative Arts, Digital Communication Solutions'),
    ('Mathematical Methods', 'Economics', 'Legal Studies', 'Business Innovation'),
    ('Mathematical Methods, Specialist Mathematics, Economics, Legal Studies'),
    ('Mathematical Methods, Specialist Mathematics, Economics, Digital Technologies'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Chemistry'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Chemistry'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Digital Technologies'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Material Solutions'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Chemistry'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Earth and Environmental Science'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Digital Technologies'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Robotic and Electronic Systems'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Earth and Environmental Science'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Chemistry'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Digital Technologies'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Chemistry'),
    ('Mathematical Methods, Specialist Mathematics, Physics, Robotic and Electronic Systems'),
    ('Biology', 'Physical Education', 'Health and Wellbeing', 'General Mathematics'),
    ('Media Studies', 'Creative Arts', 'Drama', 'Digital Communication Solutions'),
    ('Visual Arts – Art', 'Creative Arts', 'Design', 'Media Studies'),
    ('Chemistry', 'Biology', 'Nutrition', 'Mathematical Methods'),
    ('Visual Arts – Design', 'Digital Communication Solutions', 'Creative Arts', 'Business Innovation')
    ('Biology', 'Psychology', 'Health and Wellbeing', 'General Mathematics'),
    ('Biology', 'Psychology', 'Health and Wellbeing', 'Nutrition'),
    ('Biology', 'Physical Education', 'General Mathematics', 'Nutrition'),
    ('Health and Wellbeing', 'Business Innovation', 'General Mathematics', 'Legal Studies'),
    ('Biology', 'Nutrition', 'Physical Education', 'General Mathematics'),
    ('Physical Education', 'Health and Wellbeing', 'Biology', 'General Mathematics'),
    ('Physical Education', 'Health and Wellbeing', 'Psychology', 'Biology'),
    ('Biology', 'Nutrition', 'Chemistry', 'Mathematical Methods'),
    ('Visual Arts – Art', 'Creative Arts', 'Digital Communication Solutions', 'Media Studies'),
    ('Visual Arts – Design', 'Material Solutions', 'Digital Communication Solutions', 'Mathematical Methods'),
    ('Digital Technologies', 'Mathematical Methods', 'General Mathematics', 'Physics'),
    ('Digital Technologies', 'Mathematical Methods', 'General Mathematics', 'Economics'),
    ('Digital Technologies', 'Mathematical Methods', 'Creative Arts', 'Media Studies'),
    ('Digital Technologies', 'Mathematical Methods', 'Physics', 'Legal Studies'),
    ('Digital Technologies', 'Mathematical Methods', 'Digial Communication Solutions', 'Information Processing and Publishing'),
    ('Visual Arts – Design', 'Material Solutions', 'Mathematical Methods', 'Digital Technologies'),
    ('Business Innovation', 'Economics', 'Legal Studies', 'Chinese (continuers)'),
    ('Politics, Power and People', 'Legal Studies', 'Modern History', 'Chinese (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Chinese (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Biology', 'Geography'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'French (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'German (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Ancient Studies'),
    ('Economics', 'Politics, Power and People', 'Society and Culture', 'Geography'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Society and Culture'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Italian (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Japanese (continuers)'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Society and Culture'),
    ('Modern History', 'Politics, Power and People', 'Society and Culture', 'Geography'),
    ('Modern History', 'Politics, Power and People', 'Legal Studies', 'Spanish (continuers)'),
    ('English Literary Studies', 'Media Studies', 'Modern History', 'Politics, Power and People'),
    ('English Literary Studies', 'Media Studies', 'Modern History', 'Creative Arts'),
    ('English Literary Studies', 'Media Studies', 'Digital Communication Solutions', 'Creative Arts'),
    ('English', 'Media Studies', ' Visual Arts – Design', 'Digital Technologies'),
    ('Politics, Power and People', 'Legal Studies', 'Modern History', 'Media Studies'),
    ('Media Studies', 'Business Innovation', 'Society and Culture', 'Legal Studies'),
    ('Biology', 'Chemistry', 'Mathematical Methods', 'Physics'),
    ('English Literary Studies', 'Legal Studies', 'Philosophy', 'Modern History'),
    ('Legal Studies', 'Philosophy', 'Modern History', 'Politics, Power and People'),
    ('Legal Studies', 'Business Innovation', 'Accounting', 'Society and Culture'),
    ('Legal Studies', 'Accounting', 'Economics', 'Business Innovation'),
    ('Legal Studies', 'Society and Culture', 'Psychology', 'Modern History'),
    ('Legal Studies', 'Economics', 'Mathematical Methods', 'Politics, Power and People'),
    ('Legal Studies', 'Economics', 'Mathematical Methods', 'Specialist Mathematics'),
    ('Legal Studies', 'Politics, Power and People', 'Modern History', 'Society and Culture'),
    ('English Literary Studies', 'Legal Studies', 'Media Studies', 'Politics, Power and People'),
    ('Legal Studies', 'Psychology', 'Biology', 'Philosophy'),
    ('Legal Studies', 'Earth and Environmental Science', 'Politics, Power and People', 'Society and Culture'),
    ('English', 'Media Studies', 'Business Innovation', 'Visual Arts — Design'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Physics', 'Chemistry'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Physics', 'English'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Physics', 'Chemistry'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Economics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'English', 'Philosophy'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Economics', 'Psychology'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Physics', 'Chemistry'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Digital Technologies', 'Economics'),
    ('Mathematical Methods', 'Specialist Mathematics', 'English', 'Philosophy'),
    ('Mathematical Methods', 'Specialist Mathematics', 'Economics', 'Psychology'),
    ('English', 'Media Studies', 'Digital Communication Solutions', 'Visual Arts — Design'),
    ('Digital Technologies', 'Media Studies', 'Mathematical Methods', 'Visual Arts — Design'),
    ('English', 'Media Studies', 'Digital Communication Solutions', 'Visual Arts — Design'),
    ('English Literary Studies', 'Media Studies', 'Digital Communication Solutions', 'Society and Culture'),
    ('Media Studies', 'Digital Technologies', 'Visual Arts — Design', 'Drama'),
    ('Media Studies', 'Society and Culture', 'English Literary Studies', 'Modern History'),
    ('Media Studies', 'Visual Arts — Design', 'Drama', 'Digital Communication Solutions'),
    ('Media Studies', 'English Literary Studies', 'Modern History', 'Visual Arts — Art'),
    ('Media Studies', 'Business Innovation', 'Society and Culture', 'English'),
    ('Physics', 'Biology', 'Mathematical Methods', 'Chemistry'),
    ('Physics', 'Biology', 'Mathematical Methods', 'Chemistry'),
    ('Physics', 'Biology', 'Mathematical Methods', 'Chemistry'),
    ('English', 'Biology', 'Mathematical Methods', 'Chemistry')
    ('Biology', 'Health and Wellbeing', 'Psychology', 'English'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Visual Arts — Art'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Creative Arts'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Creative Arts'),
    ('Music Performance – Ensemble', 'English', 'Music Studies', 'Creative Arts'),
    ('Music Studies', 'English Literary Studies', 'Modern History', 'Society and Culture'),
    ('Drama', 'Dance', 'Music Performance – Solo', 'English'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Visual Arts — Art'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Creative Arts'),
    ('Music Performance – Solo', 'Music Explorations', 'Music Studies', 'Creative Arts'),
    ('Music Performance – Ensemble', 'English', 'Music Studies', 'Creative Arts'),
    ('Biology', 'Health and Wellbeing', 'Psychology', 'General Mathematics'),
    ('Biology', 'Health and Wellbeing', 'Psychology', 'English'),
    ('Biology', 'Chemistry', 'Health and Wellbeing', 'English'),
    ('Outdoor Education', 'Physical Education', 'Geography', 'Health and Wellbeing'),
    ('Chemistry', 'Biology', 'Mathematical Methods', 'English'),
    ('Chemistry', 'Biology', 'Mathematical Methods', 'English'),
    ('Philosophy', 'Politics, Power and People', 'Economics', 'English Literary Studies'),
    ('Biology', 'Chemistry', 'Physical Education', 'Physics'),
    ('Biology', 'Chemistry', 'Health and Wellbeing', 'Psychology'),
    ('Psychology', 'Society and Culture', 'Philosophy', 'English'),
    ('Psychology', 'Biology', 'General Mathematics', 'English'),
    ('Psychology', 'Biology', 'Mathematical Methods', 'English'),
    ('Psychology', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('Psychology', 'Society and Culture', 'Health and Wellbeing', 'English'),
    ('Psychology', 'Biology', 'Chemistry', 'Mathematical Methods'),
    ('Psychology', 'Society and Culture', 'Health and Wellbeing', 'English'),
    ('Biology', 'Health and Wellbeing', 'Psychology', 'Society and Culture'),
    ('Biology', 'Health and Wellbeing', 'Psychology', 'Society and Culture'),
# Out:
#   Cell In[34], line 95
#     ("Women's studies, 'Society and Culture', 'Psychology', 'Modern History')
#      ^
# SyntaxError: unterminated string literal (detected at line 95)

# %%
degree_cols = degree_names['Degree Name']

# %%
for i in (degree_cols):
    print(i)
# Out:
# Bachelor of Accounting
# Bachelor of Agricultural Sciences
# Bachelor of Architectural Design
# Bachelor of Architectural Design majoring in Urban Planning
# Bachelor of Arts
# Bachelor of Arts majoring in Aboriginal Studies
# Bachelor of Arts majoring in Anthropology
# Bachelor of Arts majoring in Archaeology and Classical Studies
# Bachelor of Arts majoring in Art History and Visual Culture
# Bachelor of Arts majoring in Chinese Studies
# Bachelor of Arts majoring in Creative Writing
# Bachelor of Arts majoring in Cultural Studies
# Bachelor of Arts majoring in English Literature
# Bachelor of Arts majoring in Environmental Management
# Bachelor of Arts majoring in French Studies
# Bachelor of Arts majoring in Gender and Sexuality Studies
# Bachelor of Arts majoring in Geography
# Bachelor of Arts majoring in German Studies
# Bachelor of Arts majoring in History
# Bachelor of Arts majoring in International Development
# Bachelor of Arts majoring in International Security
# ...
